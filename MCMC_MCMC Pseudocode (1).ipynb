# %%
"""
Inputs:

target distribution

initial state : float or int

n_samples : int

proposal_std= 0.1 (optional, if uniform disribution is between 0 and 1, it is most likely step sd) : float

plot = TRUE (optional, opt out of graph dk why someone would want that) : Booliean 

random_seed = None : None or int

prob_threshold = None : None or int

--------------------------

Outputs:

plot 

samples (print as df for now bc it bothers me less)

acceptance_ratio

posterior_mean

posterior_var

prob_above_t

(want to add in burn-in/convergence stuff, might be seperate function though)

"""

# %%
# target_dist(theta):
    # theta = [x_1, x_2, ...]
    # return function(theta)

# MH(target_dist, n_samples, initial_state, proposal_std, random_seed = None, plot = True, prob_threshold = None):

    # set random_seed as rng if random_seed isn't None

    # create vector to store samples
    # set initial_state as first entry in vector
    # initilaize # of accepted candidtates

    # start for loop that runs n_samples # of times
        # set current state as the previous state (samples[i-1])
        # randomly generate candidate from proposal distribution, use current state as center and propsal_std/propsoal_cov as spread
        # check and reflect each dimension or reject candidates outside bounds
        # plug current state and candidate into target probability distribution
        # calculate hastings ratio \alpha (if proposal probability distribution if symmetrical, then simplify to target_dist ratio)
        # randomly generate number u from U(0, 1)
        # accept candidate if min(1, \alpha) \geq u and increment # of accepted candidates, reject candidate if not
            # if candidate is more likley than current state, then \alpha \geq 1 and candidate will be accepted with prob 1
            # if candidate is less likely than current state, then 1 \geq \alpha and the candidate might be accepted with prob \alpha

    # plot accepted states vs probability density (estimated posterior)
            # optionally smooth sample spikes 
            # optionally graph in comparison with target posterior

    # compute MC estimates for posterior mean and variance
    # if given prob_threhold, compute MC estimate of prob that estimated parameter is greater than the threshold

    # compute acceptance rate by number of accepted candidates divide by # of candidates proposed

    # print estimates and samples
    # results

# %%
# MULTIPLE PARAMETERS
# used GeeksforGeeks: https://www.geeksforgeeks.org/maths/covariance-matrix/
# MCMC with multiple parameters being estimated requires covariance matrix
    # diagonal elements are variance and non-diaganol are covariance
    # covariance describes relationship between two variables
    # symmetric
# covariance matrix can be caluclated from data frame
# show how variables move together --> describes spread and correlation
# proposal_std describe step size, proposal_cov describes shape of step (which includes "size")
# use proposal_cov instead of proposal_std
